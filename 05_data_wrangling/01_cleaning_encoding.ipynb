# %% [markdown]
# <a href="https://colab.research.google.com/github/R786P/data-science-roadmap-2025_2026/blob/main/05_data_wrangling/01_cleaning_encoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram

# %%
# 05_data_wrangling/01_cleaning_encoding.ipynb
import pandas as pd
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Load data
df = pd.read_csv("https://raw.githubusercontent.com/IBM/telco-customer-churn-on-icp4d/master/data/Telco-Customer-Churn.csv")

print("📊 Before Cleaning:")
print(f"Total rows: {len(df)}")
print(f"Missing values: {df.isnull().sum().sum()}")
print(f"Duplicate rows: {df.duplicated().sum()}")

# 1. Handle missing values
df = df.dropna()

# Convert TotalCharges to numeric, coercing errors to NaN
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
# Drop rows where TotalCharges became NaN after conversion
df = df.dropna(subset=['TotalCharges'])

# 2. Handle duplicates
df = df.drop_duplicates()

# 3. Encode categorical variables
le = LabelEncoder()
categorical_cols = ['gender', 'Partner', 'Dependents', 'Churn']
for col in categorical_cols:
    df[col] = le.fit_transform(df[col])

# 4. Feature scaling (Z-Score)
scaler = StandardScaler()
numeric_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

print("\n✅ After Cleaning:")
print(f"Total rows: {len(df)}")
print("Sample of cleaned data:")
print(df.head(3))
# Out:
# 📊 Before Cleaning:
# Total rows: 7043
# Missing values: 0
# Duplicate rows: 0
#
# ✅ After Cleaning:
# Total rows: 7032
# Sample of cleaned data:
#    customerID  gender  SeniorCitizen  Partner  Dependents    tenure  \
# 0  7590-VHVEG       0              0        1           0 -1.280248
# 1  5575-GNVDE       1              0        0           0  0.064303
# 2  3668-QPYBK       1              0        0           0 -1.239504
#
#   PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0           No  No phone service             DSL             No  ...
# 1          Yes                No             DSL            Yes  ...
# 2          Yes                No             DSL            Yes  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# 0               No          No          No              No  Month-to-month
# 1              Yes          No          No              No        One year
# ...
