# %% [markdown]
# <a href="https://colab.research.google.com/github/R786P/data-science-roadmap-2025_2026/blob/main/19_git_soft_skills/01_git_interview.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram

# %%
# 19_git_soft_skills/01_git_interview.ipynb

print("🧠 Git Commands & Interview Tips for Data Scientists\n")
print("="*60)

# Part 1: Essential Git Commands (with explanations)
print("✅ 1. Essential Git Commands\n")

git_commands = {
    "git clone <repo-url>": "Download a repository to your machine",
    "git add .": "Stage all changes for commit",
    "git commit -m 'message'": "Save changes with a description",
    "git push": "Upload local commits to GitHub",
    "git pull": "Download latest changes from GitHub",
    "git status": "Check current status of files",
    "git log": "View commit history",
    "git branch": "List all branches",
    "git checkout -b new-branch": "Create and switch to a new branch",
    "git merge main": "Merge 'main' branch into current branch"
}

for cmd, desc in git_commands.items():
    print(f"   {cmd:<30} → {desc}")

print("\n💡 Pro Tip: Always do 'git pull' before 'git push' to avoid conflicts!\n")

# Part 2: Common Interview Questions
print("✅ 2. Top 5 Data Science Interview Questions\n")

interview_qa = [
    {
        "Q": "How do you handle missing values?",
        "A": "1. Identify pattern (MCAR/MAR/MNAR)\n   2. For numerical: mean/median/mode or model-based imputation\n   3. For categorical: mode or 'Missing' category\n   4. If >50% missing, consider dropping"
    },
    {
        "Q": "What is overfitting and how to prevent it?",
        "A": "Overfitting = model memorizes training data.\n   Prevention:\n   - Use more data\n   - Feature selection\n   - Regularization (L1/L2)\n   - Cross-validation\n   - Simpler models"
    },
    {
        "Q": "Explain p-value in hypothesis testing.",
        "A": "p-value = probability of observing the data if null hypothesis is true.\n   - p < 0.05 → reject null hypothesis\n   - p >= 0.05 → fail to reject null hypothesis"
    },
    {
        "Q": "When would you use PCA?",
        "A": "Use PCA when:\n   - Reducing dimensionality\n   - Removing multicollinearity\n   - Visualizing high-D data in 2D/3D\n   - Speeding up model training"
    },
    {
        "Q": "How do you evaluate a classification model?",
        "A": "1. Accuracy → overall correctness\n   2. Precision → false positives matter (e.g., spam detection)\n   3. Recall → false negatives matter (e.g., cancer diagnosis)\n   4. F1-Score → balance of precision & recall\n   5. ROC-AUC → overall separability"
    }
]

for i, qa in enumerate(interview_qa, 1):
    print(f"{i}. {qa['Q']}")
    print(f"   A: {qa['A']}\n")

# Part 3: Portfolio Tips
print("✅ 3. Portfolio Best Practices\n")
portfolio_tips = [
    "1. Keep README.md clear and professional",
    "2. Use meaningful file names (e.g., 01_data_cleaning.ipynb)",
    "3. Always run your notebook before saving to GitHub",
    "4. Include business insights, not just code",
    "5. Add visualizations to tell a story",
    "6. Use Colab's 'Save to GitHub' (not manual upload)"
]

for tip in portfolio_tips:
    print(f"   {tip}")

print("\n" + "="*60)
print("🎉 Congratulations! You've completed the entire Data Science Roadmap 2025!")
print("Your portfolio is now ready to showcase on GitHub and LinkedIn.")
print("\n🚀 Next Steps:")
print("   - Share your GitHub link on LinkedIn")
print("   - Apply for internships/jobs")
print("   - Keep learning and building!")
# Out:
# 🧠 Git Commands & Interview Tips for Data Scientists
#
# ...
# ✅ 1. Essential Git Commands
#
#    git clone <repo-url>           → Download a repository to your machine
#    git add .                      → Stage all changes for commit
#    git commit -m 'message'        → Save changes with a description
#    git push                       → Upload local commits to GitHub
#    git pull                       → Download latest changes from GitHub
#    git status                     → Check current status of files
#    git log                        → View commit history
#    git branch                     → List all branches
#    git checkout -b new-branch     → Create and switch to a new branch
#    git merge main                 → Merge 'main' branch into current branch
#
# 💡 Pro Tip: Always do 'git pull' before 'git push' to avoid conflicts!
#
# ✅ 2. Top 5 Data Science Interview Questions
#
# 1. How do you handle missing values?
#    A: 1. Identify pattern (MCAR/MAR/MNAR)
# ...
